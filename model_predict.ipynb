# %%
import numpy as np
import joblib
from sklearn.datasets import load_iris

# %%
model = joblib.load("./svc_model.pkl")

# %%
data = load_iris()
target_names = data.target_names

# %%
sample = np.array([[5.1, 3, 1.4, 0.2]])

prediction = model.predict(sample)[0]
probabilities = model.predict_proba(sample)[0]
# Out:
# c:\Users\GuestAcc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# c:\Users\GuestAcc\AppData\Local\Programs\Python\Python314\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(

# %%
print(target_names[prediction])
print(probabilities)
# Out:
# setosa
# [0.95198126 0.03504672 0.01297202]
